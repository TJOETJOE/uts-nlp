# %% [markdown]
# <a href="https://www.youtube.com/channel/UC80kXszNqAdWGTHFBcOKVdg"><img src="https://lh3.googleusercontent.com/3BGYLiEKEvFZ0u6eLcDbKvad__jwIRs30D19_ttfwuMv2TrJ3qovD_Lb_HGF4QvSCeVYoE2Ay6Hkfx0wN0LFV1VvILg7XIdrqR7bE9EtnbF2SwYIueV1-B33aomEwjTmkAKDY4TYopVfaSbfsBWzwfOXpoKy_ASFSrjKt_2p_E35fyTkTbES2t9GUnZ25bMjAe_Y4xqfkw-8lRqK9zCYVwlcD_e2YXUlNXs8ubJCHwZp3MAdPL3kWzLMnuVAKsiORvjt_IgCVINNcDAqfak56arvmtg4MXpcbyKSeYK2A33p0jcFnOkgddq3KhABVNqb0PRM7inpysBXMJ7-u7Q__Y4LVGdFh_gTmuPcxHQZXqS10kU_K86bOQtgqY5m9DjJ5Ixd--sxiR4evRr4LnjDH-9L-6Rcu4EZI6LXMxlANCuFGuTLgIIqrq6qgIliinjuxyuwsX-cl-pE_Y3TBcZ5dum52_O8HtkuPo3NOQXD0Pg4ZfQV11CSkeD-82HaONupDREROrrgFOriOYljzSj4438GSaK4IUTfDjP1UFMKnA6QuZGhSA0noStBSeIwTitSUsHbspxGwYm05Of9UiP-vpvhB5zGDUWl2gLpPsXxz6SDNlDGsVFekX81jNOrFnDzj-Me98FgK4AAmW4Of6Z8LN1ZjBw1MdFwGabLN94tHUMg0sPf-UJFbw5XqN0spoltuB8YmAGSyIWLHoC4eVuARcEX=w1659-h300-no?authuser=0" align="center"></a>
# # <center>Crawling Komentar Video Youtube</center>
# <hr>

# %% [markdown]
# **Tujuan** dari program ini adalah melakukan crawling (pengambilan) data komentar pada sebuah video Youtube menggunakan **Youtube Data API v3**.  pastikan aktifkan layanan Youtube Data API
#
# Jika belum memiliki **API KEY**, Anda dapat mengikuti petunjuk singkat sebagai berikut:
# 1. Login ke Google Developer Console (https://console.developers.google.com/)dengan akun Google Anda
# 2. Buat project baru dan lengkapi isian yang diminta.
# 3. Aktifkan Layanan API pada halaman project, dan cari **Youtube Data API v3**.
# 4. Dari halaman dashboard, buat kredential agar API tersebut dapat digunakan. Klik tombol **Buat Kredensial** (**Create Credential**). Lengkapi isian formnya.
# 5. Anda dapat mengakses / melihat API KEY pada tab **Credentials**.

# %% [markdown]
# #1. Import Library

# %%
import pandas as pd
from googleapiclient.discovery import build

# %% [markdown]
# #2. Fungsi untuk crawling komentar

# %%
def video_comments(video_id):
    replies = []
    limit = 500  # batas total komentar
    count = 0

    youtube = build('youtube', 'v3', developerKey=api_key)

    video_response = youtube.commentThreads().list(
        part='snippet,replies',
        videoId=video_id,
        maxResults=100
    ).execute()

    while video_response and count < limit:

        for item in video_response['items']:

            if count >= limit:
                break

            published = item['snippet']['topLevelComment']['snippet']['publishedAt']
            user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

            replies.append([published, user, comment, likeCount])
            count += 1

            # reply comment
            replycount = item['snippet']['totalReplyCount']
            if replycount > 0:
                for reply in item['replies']['comments']:

                    if count >= limit:
                        break

                    published = reply['snippet']['publishedAt']
                    user = reply['snippet']['authorDisplayName']
                    repl = reply['snippet']['textDisplay']
                    likeCount = reply['snippet']['likeCount']

                    replies.append([published, user, repl, likeCount])
                    count += 1

        # next page only if still below limit
        if 'nextPageToken' in video_response and count < limit:
            video_response = youtube.commentThreads().list(
                part='snippet,replies',
                pageToken=video_response['nextPageToken'],
                videoId=video_id,
                maxResults=100
            ).execute()
        else:
            break

    return replies

# %% [markdown]
# #3. Jalankan Proses Crawling

# %%
# isikan dengan api key Anda
api_key = 'API Key'

# Enter video id
# contoh url video = https://www.youtube.com/watch?v=5tucmKjOGi8
video_id = "wiIdWIgmevw" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2025-11-25T16:41:28Z',
#   '@tommyt1971',
#   'Makes me think that T***p got sick of Florida and <a href="http://www.youtube.com/results?search_query=%23rondefascist">#RonDeFascist</a> and wants to make himself a resident of NY again.',
#   0],
#  ['2025-11-25T16:40:53Z',
#   '@patrickhowell5578',
#   'WOW, literally WOW!<br>Fox &amp; MAGA must be imploding 😂',
#   0],
#  ['2025-11-25T16:38:29Z',
#   '@thomasdeas1941',
#   'Trumps voice is constantly horse, to many blowies or a symptom of his bad health?',
#   0],
#  ['2025-11-25T16:37:40Z',
#   '@AzzöNözzö',
#   'Does Putin have any pornographic pictures of Trump at some meeting to blackmail Trump? Trump is always Putin&#39;s dog and obeys Putin???',
#   1],
#  ['2025-11-25T16:34:50Z',
#   '@sepiasnakesigil',
#   'Good for Mamdani, but I wonder how big the overlap is between the people who find this endearing and don&#39;t judge Mamdani for meeting with Trump and the people who hated Harris for talking with Liz Cheney.',
#   0],
#  ['2025-11-25T16:34:19Z',
#   '@gsteckly',
#   'If it&#39;s something Donnie&#39;s been taking... &quot;I&#39;ll have what he&#39;s having&quot;',
#   0],
#  ['2025-11-25T16:34:10Z',
#   '@Grant-yv7by',
#   'You can call me Ray or you can call me Jay; you can call me Facist or you can call me Racist, but you don&#39;t have to call me a #@* ken big Liar.!.',
#   0],
#  ['2025-11-25T16:33:06Z',
#   '@hamzainayatbarlas1918',
#   'Zohran is the literal definition of &quot;I need new haters the old ones are becoming my fans&quot;',
#   0],
#  ['2025-11-25T16:32:26Z',
#   '@JustChrisTM',
#   'He never smiled at Melania that hard 😅',
#   0],
#  ['2025-11-25T16:30:52Z',
#   '@jjsantangelo49',
#   'You’re a good man with a dedicated team, thanks for keeping the jokes coming for the beginning half of the week while everyone else took off, we appreciate your sacrifices, happy holidays to the whole team!',
#   0],
#  ['2025-11-25T16:28:19Z',
#   '@Camus1025',
#   'Trump is such a clout chaser. He always wants to be popular, he wants to be associated with popular people, and the most he&#39;s ever managed is dongs like Hulk Hogan and Kid Rock. Now, here he gets to ride on the coattails of someone who actually won a major election that people like who&#39;s going to be mayor of the city he&#39;s from. Trump is exactly the kind of man to like something exactly as long as its popular in hopes that liking it will make him popular too.<br><br>Folks, hug your kids so they don&#39;t wind up like this.',
#   0],
#  ['2025-11-25T16:27:58Z',
#   '@user-jg3rp1ib5z',
#   'Your MRI impression is off the hook. Nailed it. 🔥',
#   0],
#  ['2025-11-25T16:26:42Z',
#   '@nunyadambizness6286',
#   'The most IMPRESSIVE part?! Mamdani got this reaction out of Trump WITHOUT bringing him a gift! or did he? 🤔🤔',
#   0],
#  ['2025-11-25T16:22:25Z',
#   '@paulzisk5174',
#   'Didn&#39;t Trump big the head of the KGB into the Oval Office',
#   0],
#  ['2025-11-25T16:18:37Z',
#   '@monsterfurby',
#   'I&#39;m actually buying that Trump supports Mamdani. Let&#39;s not forget that he <b>did</b> back the Democrats back in the day, so he at least has to be receptive to basic New York Democrat talking points. Plus, he has nothing to fear from Mamdani in terms of presidential competition. Most importantly, this is a rare occasion where the Republicans had to let him out of his bubble where his main job is to nod and vigorously defend anything his advisors tell him to defend (sometimes contradictorily, depending on which advisor got to him last). I&#39;m pretty sure that Trump would have no problem adopting the Democratic agenda if he thought it would bring him an advantage. Actually, come to think of it - if the Democrats were really smart, they&#39;d just try to flip Trump to their policy. Best case, the Republicans break from him. Worst case,  it&#39;s championed by commander orange, but you still get the policy you want.',
#   0],
#  ['2025-11-25T16:18:15Z',
#   '@chorze',
#   'The guy just wants some cool friends. Almost sad.',
#   0],
#  ['2025-11-25T16:17:42Z',
#   '@Endraken',
#   'Clearly Trump&#39;s empire needs Mamdani for some real estate  reason. Transactional first, last, and always.',
#   0],
#  ['2025-11-25T16:17:34Z',
#   '@charlesmitchell9690',
#   'You mean he realizes that the money he might owe for properties or doing business in the state and in the city might hurt his finances?  Might hurt business relations with his friends?  Then there&#39;s in order to fight against someones policies you need to know what the policies are?  In order to be able to hear what policies are being considered and have insight you sometimes need to befriend people vs be on the outside looking in.  If you&#39;re on the outside looking in you probably don&#39;t know as much az if you were befriending  such a person and willing to lend an actual ear or people to hear what is going on.',
#   0],
#  ['2025-11-25T16:15:30Z',
#   '@milohargadine1601',
#   'I’ve been waiting for a “You don’t mess with the Zohran” joke since this started',
#   0],
#  ['2025-11-25T16:12:23Z',
#   '@TheBlade996',
#   '8&gt;20 &quot;Mamdani is a charismatic swindler&quot; says F-Elon, the biggest charismatic swindler in history! 🤣',
#   0],
#  ['2025-11-25T16:09:31Z',
#   '@mageofthestorm1',
#   'Trump knows that the mayor still has authority to mess with his company if he really wants to. That&#39;s why he&#39;s kissing his butt. Trump knows who to put his brown nose for.',
#   0],
#  ['2025-11-25T16:08:07Z',
#   '@stephanieashworth6317',
#   'Maybe he&#39;ll come up with a new name for him like he did for &#39;Mark Ruby&#39;.',
#   0],
#  ['2025-11-25T16:06:47Z',
#   '@ricokohler2686',
#   'I&#39;d assume Mamdani has some dirty information about this so called president and now trump is just being a slimy hypocrite hoping for Mamdani not to talk',
#   0],
#  ['2025-11-25T16:06:41Z',
#   '@onepiece_luffysgirl',
#   'I think this is the best bit of seth this month',
#   0],
#  ['2025-11-25T16:03:21Z',
#   '@IAmAceCloudstar',
#   'He&#39;s too much of a coward to keep up his rhetoric when face-to-face.',
#   0],
#  ['2025-11-25T16:02:08Z', '@travis9472', 'Trump has a crush.', 0],
#  ['2025-11-25T16:01:57Z',
#   '@martinrogers1113',
#   'Seth’s shows are basically made for people who stopped keeping up with the world decades ago.',
#   0],
#  ['2025-11-25T15:57:48Z',
#   '@danielschmaniel7643',
#   'how did you get the mri photoshop so wrong? it&#39;s headfirst',
#   0],
#  ['2025-11-25T15:52:15Z',
#   '@aniballaboy8398',
#   'Trump will do and say anything to distract Maga from the Epstein files.....',
#   0],
#  ['2025-11-25T15:50:45Z',
#   '@wyskass861',
#   'This meeting show the true cultural power NYC actually has.',
#   0],
#  ['2025-11-25T15:49:02Z',
#   '@alancongiardo8072',
#   'What happened between the time that President Trump had made alll of those derogatory and insulting remarks about  Mayor-Elect Mamdani and this moment when they met in the Oval Office?',
#   0],
#  ['2025-11-25T15:41:26Z',
#   '@mattpinto2351',
#   '<a href="https://www.youtube.com/watch?v=wiIdWIgmevw&amp;t=130">2:10</a> It was fast, but the writing on this bit was absolutely spot on',
#   0],
#  ['2025-11-25T15:37:09Z',
#   '@jodygoodman8540',
#   'Is Trump speaking of himself????',
#   0],
#  ['2025-11-25T15:35:24Z',
#   '@johnandrews3568',
#   'Why didn&#39;t/isn&#39;t the media calling trump out for admitting he&#39;s a fascist?? WTAF?',
#   0],
#  ['2025-11-25T15:34:13Z',
#   '@Michelle-n7f',
#   'That doesn&#39;t  even LOOK like Trump !',
#   0],
#  ['2025-11-25T15:33:17Z',
#   '@waltergodsoe5526',
#   'The only recipients of Communist largess are Billionaires. Bailout Banks, Bailout Manufacturers, and soon bailout the companies who threw all their resources at AI.',
#   0],
#  ['2025-11-25T15:32:10Z',
#   '@shinankoku2',
#   'Of course Trump loves Mamdami. Trump <b>has no political core.</b> He just loves winners. And hot people. That’s his whole jam. And Mamdami is a good looking winner.',
#   0],
#  ['2025-11-25T15:31:24Z',
#   '@-xirx-',
#   'Zoran Mamdani is the greatest gift to Democrats, and half the do-nothing Democrats don&#39;t even recognise it.',
#   0],
#  ['2025-11-25T15:30:46Z',
#   '@UsusAntiquior62',
#   'Don&#39;t be silly &#39;Madmani &#39;and his facial expressions betray a seething contempt for Trump. Anyone  who thinks differently needs to do the psychology of body language 101',
#   0],
#  ['2025-11-25T15:28:15Z',
#   '@FredricoMayonetti',
#   'Notice, trumps only talked back to female reports. He’s only beaten females in elections. <br>He will never say stuff like that to a man’s face. Coward.',
#   1],
#  ['2025-11-25T15:27:51Z',
#   '@Michael_Smith-Red_No.5',
#   'Did Seth Meyers just fire a couple of Thermonuclear missiles at my ship?',
#   0],
#  ['2025-11-25T15:26:45Z',
#   '@emmgeevideo',
#   'Seth, say what you will about Trump, but he&#39;s not stupid.  He has something up his sleeve.  This isn&#39;t what it looks like, mark my words.',
#   0],
#  ['2025-11-25T15:24:13Z',
#   '@neilgj6305',
#   'MAGA did&#39;nt seem to have a problem with a REAL COMMUNIST in the form of Sergey Lavrov , Russia’s Foreign affairs Minister when he visited the White House in 2017',
#   0],
#  ['2025-11-25T15:22:46Z',
#   '@D.A.OhK.',
#   'Has anyone told MAGA that Trump is turning our economy into a collective of state-owned industries?',
#   0],
#  ['2025-11-25T15:20:12Z',
#   '@ubermonkee',
#   'I just have to say, having the daredevil as the mayor of NY is boss!  <br>...he is Charlie Cox, isn&#39;t he? I&#39;m not fooled!',
#   0],
#  ['2025-11-25T15:17:16Z',
#   '@brooksrogers1975',
#   'Tne man&#39;s name is zohrAN, not ZOhran,',
#   0],
#  ['2025-11-25T15:15:18Z',
#   '@kelleyceccato7025',
#   'Trump is actually criticizing someone ELSE for having a grating voice??',
#   0],
#  ['2025-11-25T15:15:01Z',
#   '@nickgallagher69',
#   'Looks like whoever is cutting Elon&#39;s hair these days is the real terrorist!  Come on, guy, you&#39;re worth a trillion dollars, but you still walk out of the house looking like that? 😂',
#   0],
#  ['2025-11-25T15:14:56Z',
#   '@y2ssimon',
#   'I wonder what Zohran said in that meeting that he made him talk like that...this is going to be interesting and the best ..the heads of the extremist fanatics blowing up.',
#   0],
#  ['2025-11-25T15:13:52Z',
#   '@BudPrindle',
#   'If Trump is the only one who can save us,then we are all doomed',
#   0],
#  ['2025-11-25T15:10:58Z',
#   '@thetonupsband9053',
#   'Trump is a lifelong Democrat. He’s from NYC. His whole thing is a reality show act. He,s a fake. He donated to the Clinton’s. He’s a B level actor. He’s just a mouthpiece. He says what he’s told. But sometimes he goes off script because he’s an ego maniac half ass actor.  Stephen Miller and Steve Bannon are in control big picture. I’m not sure they are happy with him going off script here. How hard is it to see reality..?',
#   0],
#  ['2025-11-25T15:10:44Z',
#   '@brianshaker1885',
#   'This literally made people like me... like Trump. I mean, let&#39;s be clear here, I hate the guy... but there&#39;s clearly a side to Trump that maybe in a thousand years could he a decent enough guy in a different life. (That doesn&#39;t happen to everybody, Steven Miller and Caroline Leavitt are proof positive of that!)',
#   0],
#  ['2025-11-25T15:10:21Z',
#   '@fatimamir6487',
#   'Can&#39;t believe this happened so smooth 😂😂😂',
#   0],
#  ['2025-11-25T15:10:19Z',
#   '@wyskass861',
#   'Trump as many pathological narcissists are actually quite easy to manipulate if you understand the psychological dynamics. Their self delusion prevents them from seeing it too.',
#   0],
#  ['2025-11-25T15:08:28Z',
#   '@markhagen1329',
#   '&quot;Joke boy.&quot; LOL. I love it.',
#   0],
#  ['2025-11-25T15:08:14Z',
#   '@rcreative1',
#   'Donald always agrees with the last person he meets with. It is worth remembering that JD Vance made the famous meeting with Zelinsky toxic. Donald was friendly before JD chimed in.',
#   0],
#  ['2025-11-25T15:07:12Z',
#   '@keenanmccracken6758',
#   'It&#39;s because the far left and right aren&#39;t so far from each other when you take all the hate out of it',
#   0],
#  ['2025-11-25T15:06:48Z',
#   '@vickijones2013',
#   'Maybe Zohran should stay around rump keep the Ghouls away especially Stephen Miller',
#   0],
#  ['2025-11-25T15:05:40Z',
#   '@pupperbop',
#   'well the satire aside im glad they&#39;re getting along',
#   0],
#  ['2025-11-25T15:03:00Z', '@Dusky-i5b', 'fox is fake news!', 0],
#  ['2025-11-25T15:02:05Z',
#   '@williammayhoperights',
#   'he super rich cartel, did mind taking US health care, throwing nuke bombs on US[testing]taking food, snap, the cartel tell you the rich can do what ever they want, like tear up the white house, make billions from graft,or rape underage girls,illegal &#39;surveillance&#39; HELL NO! stop the &#39;PPP&#39; stop project 21, restitution to HOPE, or their is no economy,and worse!be &#39;FIIT&#39; STOP ice! end the famine in Gaza, on average 2 kids a day are killed in Gaza, sense the &#39;fake&#39; peace treaty!be non violent HOPE',
#   1],
#  ['2025-11-25T15:00:26Z',
#   '@williammayhoperights',
#   'tRump, a spoiled billionaire stealing from working folks! he thinks on his orders;good old  working folks are going to attack the left. he is dead wrong.the good old boys would have to give up all pre-martial sex, support child trafficking and child abuse, embrace Epstein and using little boys and girls, destroy ALL rock and roll, country music ,jazz, hip hop, destroy all natural outdoor camping, to support a super rich billionaire class they want at their whim to dispose of who ever however the rich  want. the right wing &#39;good old folks&#39; now know that maga management think they are dependable fools!the original maga base are enraged, where indeed are the EPSTEIN FILES?they do not Hate their kids getting health care, education, they do want the giant corporations and super rich to have workers have no rights and polluters making billions to make them and their kids sick! they are disgusted and enraged at the billionaire pedophile cabal! that is maga-management! tRump is correct to actually say the good old boys on the right can be terrifying, they are called AMERICANS, and the maga FAITHFUL are FAITHFUL NO MORE! they have been betrayed and are very angry at everything they thought they were supporting being a LIE! those on the left are who they go to concerts and movies with, see when they are eating dinner out and go camping near . we are welcoming them back, WE HATE THE BILLIONAIRE ELITES, PEDOPHILE, criminal, CABAL MONSTERS! the elits are trying to take all our rights the elits are trying to divide US and use US! but they forgot How they originally requited them, forgot they now know their new right REPUBLICAN management are supper rich lairs, working with bought off corrupt high technology to own every thing and make sure ALL workers have no RIGHTS, the good old boy right wing are engaged, but not at Nancy Polllices husband or Joe Bidden or governor WALTZ, they are made they are mad at lying hoes, controllers,police violence, Epstein/tRump/Mus-Rat,elites crime family cabal! yes  mega supporters were tricked, but their not stupid, and they like Colbert,Kimmel and Will Smith, they don&#39;t have to agree with ALL they say, but they support their right to SAY it! they don&#39;t like &#39;little smokey[Vance]Crash Petal, hex-spell, VOID, or Steve &#39;mule-ler&#39;! or the the other fascist hypocrites, the main maga they made a mistake but love this country and are not STUPID,and that was what the maga management was counting on! you are NO LONGER their minions,once you see the little ugly orc behind the green curtain you can never stop seeing him!they want their kids to be able to read,have health care a livable wage,and have their woman and kids not to be raped and molested, they want freedom, rights to a fair trial, and truth, they have left maga for a chance to get AMERICA back again. i  came from the blue collar, worked my whole life, i know my people, maga management have no clue in their gated mansions who we are! they want a gold plated white house with an enormous ball[Epstein&#39;s BAAl room], while taking folks medicine,food,while all of US, can&#39;t pay taxes, make their mortgages and rent! HELL NO!! the irony it is  tRump and maga billionaire ultra right hate maga followers more than the hate the rest of US! they think you are STUPID enough to believe them, you don&#39;t deserve your rights or pay checks! HELL NO! you were just lied to by &#39;liars for hire&#39;[Carl Grossman quote] professional con guys!!we the AMERICANS don&#39;t want you lying, super rich, self pitying, criminals,we all of US, want maga out and AMERICA BACK AGAIN!i hang on with safe renewable clean energy. that kind of power can turn the tide, maybe, we must try!! when i was doing juggling shows for people with cancer, i never asked what religion they were, weather they smoked pot, drank alcohol,were rich,poor, democrat, Republican, what race they were, etc..pain breaks and caring are for US AL! so is freedom. i saw the truth,folks ...
#   1],
#  ['2025-11-25T14:59:31Z',
#   '@Martha-q3s8z',
#   'I honestly think that he confused Mamdani with a south Arabian prince and he was waiting for gold presents from him. Love you Seth and great team.',
#   0],
#  ['2025-11-25T14:58:17Z',
#   '@juanpunkace',
#   'I’m still waiting for all the Republicans that swore they’d leave the country when Obama was elected to gtfo.',
#   0],
#  ['2025-11-25T14:57:52Z',
#   '@creaturreclothing',
#   'They microdosed him a bit hard that morning.',
#   0],
#  ['2025-11-25T14:53:06Z',
#   '@rcnotes',
#   'Trump has never been happy. He&#39;s taking massive amounts of mood altering drugs.',
#   0],
#  ['2025-11-25T14:51:49Z',
#   '@donnasitu7451',
#   'LOL, Elon calling someone else a swindler is so cringe.',
#   0],
#  ['2025-11-25T14:49:31Z',
#   '@cshortridge1',
#   'That handshake with 2 pats happened twice.  NOBODY gets that! 😂',
#   0],
#  ['2025-11-25T14:46:59Z',
#   '@eightball8888',
#   'Wait... I thought he pardoned Eric Adam&#39;s to  install him into his maga group',
#   0],
#  ['2025-11-25T14:44:55Z',
#   '@joshbarrigada',
#   'CORRECTION: THERE ARE NO STAR SHAPED TEARS ON THAT UNICORN. (super easy to illustrate , 5 mins max)',
#   0],
#  ['2025-11-25T14:44:26Z',
#   '@williammayhoperights',
#   'this &#39;birthday card&#39; is more evil than folks realize. the objectification of a woman&#39;s[girls] body by a known sex offender,sending compliments to a known pedophile human sex trafficker. tRump says VIOLENCE in the home is not a real crime! Hell yes it is! by his standards,raping your wife, daughter?son?beatings and bulling are not crimes? when done in a house?[it was not a &#39;home&#39; for the victims!]an apartment? by a property &#39;owner? a hotel? murder? so 2 way morrows in a hotel room, video cameras,without consent are not crimes?[only the severest, known repeat criminals, with a court order, and  pubic servants, police, military, do you have a right to video with out their consent, they work for US! that&#39;s why we allow them weapons!]broken bones,child rape, not REAL crimes? i can tell you, to US the victims those crimes are very real! this is fact:every 74 seconds in the US,a woman is raped. that we KNOW of, every 9 minutes a child is  raped,THAT WE KNOW OF!many pedophiles have raped over 150 kids before they are caught, rapist also are a high number of repeat offences .at least 80% of rapes and child molestation goes unreported!! FACT: 34% of all murders of woman are done by their partner!!the rate of murders of children done by their dad or mom&#39;s partner are also incredibly high. surveillance has been a great tool for human traffickers, to locate, harass victims, and folks like me[&#39;whistle blowers!]illegal surveillance used rape and terror on me to steal intellectual property!6 members of my family are dead,others treated unjustly, to stop them&#39;helping me&#39;.in my case illegal surveillance stolen royalties, worth billions [tRumps, Musk-Rats,P.sTeal, all with unexplained millions!]when they were first raping me, their catch phrase was they wanted to be&#39;a man with money!&#39;[see above list] i as a 5 time cancer survivor, i seemed venerable, but they killed 6 members of my family, folks that would have helped me, to exploit me, NO MORE made others of my families life hell for helping me! NO MORE! that is what Palintear represents, away to have all  YOUR data, to sell to you that is it&#39;s benign face, to find out where your kids is, your wife,do you own a gun? close friends or family, where are they?now the victim is not only raped by one a-hole, but i videoed. groups of strangers are viewing anguish in private lives! you were &#39;groomed&#39; for this, &#39;liars for hire&#39;[C.G. quote] went on certain talk shows and told you their private life, making it &#39;OK&#39; to use others, HELL NO!and the super rich, with availability to technology all of US lack, were ably to be tracked, isolated, tortured,[what they have done to me for last 23 years, but for decades before that,sense i testified against nukes in 1984, almost non stop!]the trauma of being raped, molested lasts a life time. it fills our prisons and jails, with victims,broken by agony and monsters.abusers can pray on the innocent there also! and not only the prisoners do this,some guards are career criminals! and if a violator gets greedy, or a more powerful violator wishes to silence him, see EPSTEIN! he is silenced. before i realized i was being &#39;targeted&#39;[harry potty]i was pregnant with terminal cancer. because i had went through this terrible cancer before i knew what i could be in for. my suffering was extreme,i was told by a man about Elisabeth Fritzel, a young girl raped as a teenager,locked in her basement, by her dad. she gave birth on the floor to 6 of his kids! alone...so&#39;he said &#39;i had it easy,what was my problem?&#39; well thank God she did not have the cancer i had, she would have died, but when i tried to find out who this girl was, where she was, he laughed and drove away. the thugs violating me knew where she was, this was 10 years of her 20 year ordeal, they KNEW! they watched! she made them money!they allowed daddy-o to build apartments over he basement hell for a closer view! but th ...
#   1],
#  ['2025-11-25T14:40:01Z',
#   '@dbspecialistrobins7533',
#   'That was the most racist press conference I&#39;ve ever seen.  Shame on you once again America. Can you get any lower.',
#   0],
#  ['2025-11-25T14:36:50Z',
#   '@asterr6456',
#   'The bad faith questions about taking a train or bus are so unserious',
#   0],
#  ['2025-11-25T14:34:20Z',
#   '@summerpiggee4043',
#   '❤❤  music 🎵 bit❤ moderation',
#   0],
#  ['2025-11-25T14:33:57Z',
#   '@andymclellan6502',
#   'That&#39;s the full crowd from his first inauguration. Lol',
#   0],
#  ['2025-11-25T14:33:18Z',
#   '@SpiderGweeb',
#   '<a href="https://www.youtube.com/watch?v=wiIdWIgmevw&amp;t=302">5:02</a> That would be an LSD acid or shroom trip not a Molly or ecstasy trip but I love the unicorn variation of big strong guy big muscles',
#   0],
#  ['2025-11-25T14:32:42Z',
#   '@richardgoodwin6652',
#   'Trump&#39;s in so much Epstein trouble that he&#39;s finally trying to be nice to win some sympathy.',
#   0],
#  ['2025-11-25T14:31:14Z',
#   '@jayceparkin959',
#   'I just want to say that Elon is an uncharismatic swindler.',
#   0],
#  ['2025-11-25T14:29:03Z',
#   '@curiositypiqued6573',
#   'Dyk;  that mamdani is the only boy for mira nair...her only child and anonly boy for mira; ie the famous filmmaker',
#   0],
#  ['2025-11-25T14:28:54Z',
#   '@chrishenson4450',
#   'Mamdani did play this very well. But don&#39;t forget the &quot;Art of the Deal&quot; which says over and over to come out swinging hard and then, when your opponent least expects it, make a few easy concessions to give them the impression they are somehow winning. And don&#39;t ignore the reaction on the far left where people feel totally betrayed by Mamdani for even talking to Trump. By saying the words &quot;I think a lot of conservatives are gonna like working with him,&quot; Trump is signaling to Mamdani voters that they might have been duped by someone who is really just another conservative. Trump is not a smart or nuanced man at all. But his one skill is in manipulating people and that includes his supporters and his enemies in equal measure.',
#   0],
#  ['2025-11-25T14:28:07Z', '@montenegro4589', 'So this is left humor lol', 0],
#  ['2025-11-25T14:26:53Z',
#   '@PC-tz6kb',
#   'I hate the orange idiot but he does look so happy &amp; comes across so charmingly. Omg he just needs to be around nicer people.',
#   0],
#  ['2025-11-25T14:26:07Z',
#   '@warriorwarrior4958',
#   'Trump was giddy because someone told him that Mamdani was actually better than Bubba and Trump couldn&#39;t contain his anticipation. 😂😂😂😂',
#   0],
#  ['2025-11-25T14:24:23Z',
#   '@richardreynolds6398',
#   'Why do people still listen to the bloated orange clown?  He lies likes he breathes.<br>Never vote for Republicans again.',
#   0],
#  ['2025-11-25T14:23:36Z',
#   '@warriorwarrior4958',
#   'Trump is NOT charismatic. 😂😂😂😂',
#   0],
#  ['2025-11-25T14:22:56Z',
#   '@pethcir',
#   '&quot;you wanna go on the roof&quot; had me cackling. This is a top 5 closer look for sure',
#   1],
#  ['2025-11-25T14:21:06Z',
#   '@kimb6974',
#   'I still want to lnow if anyone told the felon-in-thief that an MRI is done wth magnets.',
#   0],
#  ['2025-11-25T14:20:23Z',
#   '@Wayzor_',
#   'You can&#39;t help but like the guy.',
#   0],
#  ['2025-11-25T14:19:19Z',
#   '@Janice-n8f8l',
#   'People, look at Trump&#39;s nostrils. Not normal.',
#   0],
#  ['2025-11-25T14:18:16Z',
#   '@masternoob9673',
#   'Safe to say there’s a very good reason Frump decided to stay seated that entire time 💀',
#   0],
#  ['2025-11-25T14:18:00Z', '@summerpiggee4043', '❤❤❤ sweet❤', 0],
#  ['2025-11-25T14:15:37Z',
#   '@ultragodzilla117',
#   'i dont know what it is, but theres something kinda sweet about this lol. imagine if they become best friends and team up and save the world. i can see it.',
#   0],
#  ['2025-11-25T14:15:35Z',
#   '@OpinionsNoOneCaresAbout',
#   'Yeah...I&#39;m sure as soon as Mamdani won, ALL of Hannity&#39;s friends were calling him. &quot;Oh no, he won...I gotta call Sean about this!&quot;',
#   0],
#  ['2025-11-25T14:15:22Z',
#   '@enteringpolaris',
#   'As someone who was a kid in the 80s and 90s, you really wonder how we got to this point; where if you&#39;re just a regular dude who&#39;s concerned about regular stuff like other people&#39;s wellfare, health and the environment, it gets you regarded as a communist, marxist, socialist, extremist jihadist that&#39;s out to destroy society, force everyone to change their sex, poison the water supply and rob several Walmart stores in the process. Can we please go back to being at least a LITTLE normal again in our rhetoric...?',
#   0],
#  ['2025-11-25T14:14:04Z',
#   '@maryb7596',
#   'To be fair, if I met Zohran Mamdami, I&#39;d look at him the same way Trump does.',
#   0],
#  ['2025-11-25T14:14:03Z',
#   '@jayceparkin959',
#   'I was going to say about that is surrounded by Trump. Maybe it&#39;s not his fault. He&#39;s surrounded by Terminators poker face creep looking guys all around him. <br>Maybe that&#39;s what he should do. He should change everything around him and everybody around him. Put a happy face people you know. Maybe that will help him be more happy',
#   0],
#  ['2025-11-25T14:10:37Z',
#   '@CristinaMicheletti-j7k',
#   '😂😂😂remember Trump best friend Is putin a true comunist KGB',
#   0],
#  ['2025-11-25T14:06:23Z',
#   '@maybesomeone7227',
#   'Trump so happy to see someone with a charming personality, after enduring all the GOP Gargoyles...😂',
#   0],
#  ['2025-11-25T14:06:19Z',
#   '@EugeneProvencio',
#   'Choose between a Communist or stupidity. Stupidity wins again.',
#   0],
#  ['2025-11-25T14:04:33Z',
#   '@CraftAmundous',
#   'These people are psycho. Too many industrial chemical sprays.',
#   0],
#  ['2025-11-25T14:00:59Z',
#   '@laurad324',
#   'How does any 80 year old think he’s hotter than someone in their 30s? Lol',
#   0],
#  ['2025-11-25T14:00:38Z',
#   '@billhaynes400',
#   'MAGAs are in dire need of picking up a dictionary.  Throwing out labels without knowing what they mean is typical MAGA moronic.',
#   0],
#  ['2025-11-25T14:00:33Z', '@sera1996', 'More MRI impressions!', 0],
#  ['2025-11-25T14:00:07Z',
#   '@laurad324',
#   'Omfg that’s the exact face that South Park has been using for how he looks at the devil when he gets in bed with him!😂😂😂',
#   0],
#  ['2025-11-25T13:56:27Z', '@sellam8286', 'Save america from AIPAC', 0],
#  ['2025-11-25T13:53:12Z',
#   '@Hotrod-g7r',
#   'Trump just ran across an actual bulshit artist and got bullshitted that&#39;s what happened',
#   0],
#  ['2025-11-25T13:56:14Z', '@Seven-ce9zn', 'Imagine being this delusional', 0],
#  ['2025-11-25T13:52:56Z',
#   '@michaelmccoy1794',
#   'So 💩 is ok with being called a despot and a fascist.',
#   0],
#  ['2025-11-25T13:50:30Z',
#   '@jennyjohns2012',
#   'maga, is your head exploding 🤯🤯🤯',
#   1],
#  ['2025-11-25T13:47:57Z',
#   '@MrDeadsr',
#   'So trumpo has similar ideas to Mamdani. So hes a socialist to?',
#   0],
#  ['2025-11-25T13:46:42Z',
#   '@Brannybou',
#   'well, he did blow bubba, wanting a bubba 2',
#   0],
#  ['2025-11-25T13:45:35Z',
#   '@iffoic0424',
#   'Trump was like when George met Tony on Seinfeld.',
#   0],
#  ['2025-11-25T13:43:18Z',
#   '@jennyjohns2012',
#   'This is a Southpark episode 😂😂',
#   10],
#  ['2025-11-25T13:42:21Z',
#   '@frankbenevolence',
#   'Correction: you missed some important context, Mamdani was rapping about the holy land foundation after they got caught using money for 9/11 victims to directly fund terrorism. Which is worth mentioning.',
#   0],
#  ['2025-11-25T13:42:21Z',
#   '@kenpachi1989',
#   '&quot;Because that&#39;s who the Democratic party elected&quot;. They must have missed the part where THE PEOPLE vote, not the members of a party.<br>If the Republicans didn&#39;t want Mamdani, maybe they should have tried sending a better candidate against him, or do a better job at the federal level. I know, crazy idea.',
#   0],
#  ['2025-11-25T13:41:27Z', '@JMan-jj8ic', 'Trump has the HOTS for Mamdani.', 0],
#  ['2025-11-25T13:39:55Z',
#   '@b3productions974',
#   'Let&#39;s not sit here and pretend hedgehog Pikachu Chia pets would not be a best-seller',
#   0],
#  ['2025-11-25T13:39:30Z',
#   '@billyc16',
#   'Was the nip slip at <a href="https://www.youtube.com/watch?v=wiIdWIgmevw&amp;t=616">10:16</a> necessary? I was eating, now I have to go remove my eyeballs.',
#   0],
#  ['2025-11-25T13:38:07Z',
#   '@zombieowen',
#   'Correction, you don&#39;t go into an MRI feet first when you&#39;re getting your brain scanned.',
#   0],
#  ['2025-11-25T13:35:33Z',
#   '@Amystic-ery',
#   'Why is trump so dumb?????? Can&#39;t believe this is real life',
#   0],
#  ['2025-11-25T13:34:40Z',
#   '@tiffanymarie9750',
#   'I think Trump just adores any attractive youngish person who is nice to him in person.',
#   0],
#  ['2025-11-25T13:34:06Z',
#   '@tommyt1971',
#   '“I’ve been called worse than a despot.” Yeah, he doesn’t even know how bad that is.',
#   0],
#  ['2025-11-25T13:29:28Z',
#   '@LaverneAcome',
#   'Trump is a moron ,we don&#39;t need him',
#   0],
#  ['2025-11-25T13:28:43Z',
#   '@saikirannarayanaswami1618',
#   'This is the weirdest thing that&#39;s ever happened in that country. Not the Jan 6th 2021 riots, not anything Musk did. Good or bad, this is the single weirdest incident to ever happen.',
#   0],
#  ['2025-11-25T13:27:15Z',
#   '@jno488',
#   'Then leave New York!! You won&#39;t be missed!',
#   0],
#  ['2025-11-25T13:25:11Z',
#   '@marvech9830',
#   'Why do they keep calling people they don&#39;t like communists but are totally fine with Trump licking Putin&#39;s boots?',
#   0],
#  ['2025-11-25T13:57:40Z',
#   '@Seven-ce9zn',
#   'Putin is the furthest thing from a communist, for a start.',
#   0],
#  ['2025-11-25T13:22:51Z',
#   '@hellyan35867',
#   'Is Trump being an evil genius? This must be really disarming.',
#   0],
#  ['2025-11-25T13:21:22Z',
#   '@KDSchiester',
#   'Trump is a psychopath, nothing he says last longer than when it comes out of his poop pipe.   No morols, pathological liar, and wanna be tough guy that ACTUALLY WEARS DEPENDS…and Mandani knew not to suck up to him and that threw trump off…..some great videos on how experts in psych reviewed that meeting are on youtube….',
#   0],
#  ['2025-11-25T13:19:43Z',
#   '@jrfinnan',
#   'Mamdani: &quot;You think I&#39;m some commie socialist, don&#39;t you? (Whisper) Hail hydra.&quot; <br><br>Trump : Super wide grin.',
#   0],
#  ['2025-11-25T13:18:46Z',
#   '@civicilian',
#   'If only Trump were like him we wouldn&#39;t be in this mess 😮',
#   0],
#  ['2025-11-25T13:17:51Z',
#   '@CliffPerkins-f6z',
#   'Zoharan is the Snake Charmer extraordinaire <br>Satan mere putty in his Hand&#39;s!!!!',
#   0],
#  ['2025-11-25T13:17:04Z',
#   '@runek.rasmussen5320',
#   'Anyone who has had a crush on someone knows how awkward they behave being in the same room of that person. That is what happens here. Trump has a crush on Mamdani.',
#   0],
#  ['2025-11-25T13:14:56Z',
#   '@waqarbakhsh6482',
#   'The dude chanelled the whole south Asian nephew visiting elder relatives thing. Well done Mamdani',
#   0],
#  ['2025-11-25T13:14:43Z',
#   '@Whycantibeyoutube',
#   'I don&#39;t understand why the idea is that trump was charmed and Mamdani hasn&#39;t agreed to play ball with Trump. I think the latter is far more likely. Hopefully he didn&#39;t play all of NYC.',
#   0],
#  ['2025-11-25T13:06:35Z',
#   '@tenitchyfingers',
#   'First time I ever looked at Trump and said “gworl same” aloud. And I’m not even from the US. But I just am so impressed with mayor elect Zohran Mamdani. I heard him speak for 5 minutes and was immediately like “we gotta take notes! QUICK!” to the left in my country. I really hope he gets to do what he promised he’s gonna do.',
#   0],
#  ['2025-11-25T13:05:19Z',
#   '@5cloudwalker',
#   'Canada here so sick of Americans take on socialism. Canada and Europe have consolidated doctors, salaries and medical supplies to make it more affordable not unlike going to Walmart for your groceries and shopping. On top of that Canada and Europe look after at citizens with public healthcare paid by our taxes. <br>very much like in the United States Americans pay exorbitant amounts of money for their military … but you don’t hear Republicans calling the military socialistic. <br>And what is America protecting?  The right for doctors to have exorbitant salaries, and make sure that insurance companies who are the middleman are making money handover fist with medical insurance. Canada and Europe have both. We don’t bankrupt our citizens just to stay healthy or live.',
#   0],
#  ['2025-11-25T13:05:19Z',
#   '@68hoffman',
#   'the only thing trump willl admit too is being guilty of being a fascist piggy',
#   0],
#  ['2025-11-25T13:03:55Z',
#   '@wren.ty1981',
#   'Is the Mamdani-Trump meeting, the beginning of the whole world breathing a GIGANTIC sigh of relief... are we ALL..... FINALLY (!!!!) going to begin the ascent up the bell curve.... out of the depths of hopelessness and despair...??!!!! <a href="UCkszU2WH9gy1mb0dV-11UJg/rocket-red-countdown-liftoff"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/hf90Xv-jHeOR8gSxxrToBA"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/hf90Xv-jHeOR8gSxxrToBA"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/EvkfY6uNC5OykQOewoCQAQ"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/EvkfY6uNC5OykQOewoCQAQ"></a>\r<br>Seth&#39;s/ his team&#39;s frugal assessment of Mamdani&#39;s charisma makes me wonder ... JEALOUS MUCH??? What??? You&#39;ll are too &quot;intelligent&quot; to celebrate a momentary win... no matter how STUPENDOUS, AMAZING AND UNEXPECTED!??\r<br>You guys&#39; and the commentors&#39; cautious scraps of optimism be damned... I&#39;m going to effin&#39; celebrate!!!!\r<br>Kudos Mamdani yaara... meri jaan!!! Tujh pe vaari jaaoon!!!! \r<br><a href="UCkszU2WH9gy1mb0dV-11UJg/ePgfY-K2Kp6Mr8oP1oqAwAc"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/medal-yellow-first-red"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/finger-red-number-one"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/text-yellow-goal"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/jPgfY5j2IIud29sP3ZeA4Ag"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/jPgfY5j2IIud29sP3ZeA4Ag"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/jPgfY5j2IIud29sP3ZeA4Ag"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/KsIfY6LzFoLM6AKanYDQAg"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/KsIfY6LzFoLM6AKanYDQAg"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/KsIfY6LzFoLM6AKanYDQAg"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/KsIfY6LzFoLM6AKanYDQAg"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/KsIfY6LzFoLM6AKanYDQAg"></a> \r<br>May the most powerful, positively impacting powers be with you !!!!!',
#   0],
#  ['2025-11-25T13:03:27Z',
#   '@innerlocus',
#   'So, Trump thinks if you like him, he&#39;s no longer a felon, and you can change your mind that he&#39;s a despot.',
#   0],
#  ['2025-11-25T13:02:56Z',
#   '@seabassvn',
#   'Of course he love Mamdami. Mamdami is everything he’s not: smart, good looking, popular. And of course the orange utan doesn’t have the balls to tell him to his face what he’s been saying to the media. Dumpy is a scared  little boy with no balls.',
#   0],
#  ['2025-11-25T13:00:43Z',
#   '@worldssmallestfan',
#   '<a href="https://www.youtube.com/watch?v=wiIdWIgmevw&amp;t=410">6:50</a> I know this has been said a lot recently, but I still think Trump is in the closet, probably bi, but still',
#   0],
#  ['2025-11-25T12:59:13Z',
#   '@sandrajones5247',
#   'As soon as Trump gets mad at Mamdani he&#39;ll send the Nat&#39;l Guard in 😂😂😂',
#   0],
#  ['2025-11-25T12:58:48Z',
#   '@karmachameleon326',
#   'Hilarious listening to the sycophantic media figures trying to queue up their ‘gotcha’ questions, thinking the fascist god-king wanna-be would love it, then little lord Cheeto cuts them off and makes them look stupid. They still think that Trump has an actual agenda, or beliefs, or some sort of morality. He doesn’t. He just loves whoever sucked up to him last. Mamdani did a great job of playing Trump.',
#   0],
#  ['2025-11-25T14:00:43Z',
#   '@Seven-ce9zn',
#   'The questions are 100% fair and this media bashing is a tired shtick, and FYI given that its the obvious objective, it doesn&#39;t make you sound smart whatsoever. In what world a US president invites a person who called him a fascist despot to the white house? Not saying Zohran did any wrong, but what question would you ask?',
#   0],
#  ['2025-11-25T12:58:37Z',
#   '@OnlyAtJaMart',
#   'Can you lose your mind so hard that you start making sense on rare occasions?',
#   0],
#  ['2025-11-25T12:57:28Z',
#   '@ericericson3535',
#   'People, this is a huge difference between Socialism and Socialist. If you are on Medicare and Medicaid, you are benefitting from Socialism.',
#   0],
#  ['2025-11-25T12:56:00Z',
#   '@johnhalsall1878',
#   'I still haven&#39;t heard a good reason why Trump has so utterly changed about Mamdani.  It&#39;s so weird.',
#   0],
#  ['2025-11-25T13:17:50Z',
#   '@PhilipK-xk4by',
#   'Trump is not a complicated person.<br>All he wants in life are compliments, gold and McDonald’s.',
#   0],
#  ['2025-11-25T12:55:49Z',
#   '@Ross-v7r',
#   'Trump is clearly afraid of his bottom line being threatened with his buisness interests in New York. Trump has no ideology or political leanings, the ony thing he cares about is money. The sooner his zombie base wake up to that fact the better...',
#   0],
#  ['2025-11-25T12:54:57Z',
#   '@ainulkhairilezral7200',
#   'What can I say? You don&#39;t mess with the Zohran.',
#   0],
#  ['2025-11-25T12:54:55Z',
#   '@Zetalpa187',
#   'Ted Cruz, world&#39;s dumbest politician: &quot;Communist jihadist...&quot; Elon Musk world&#39;s biggest hypocrite: &quot;charismatic swindler&quot;',
#   0],
#  ['2025-11-25T12:54:49Z',
#   '@jprsfragoso',
#   'Credit to Mamdani, he cracked the code.<br>All of Trumps goons hate him, but he&#39;s useful to making their plans go forward, so they pretend to be his friend.<br>Instead of distancing and saying &quot;Im not gonna bother interact with that fascist&quot;, Mamdani just said &quot;I can play that game too&quot;',
#   0],
#  ['2025-11-25T12:53:33Z',
#   '@sandrajones5247',
#   'Let&#39;s go South Park! The face is already there for you😂😂😂',
#   0],
#  ['2025-11-25T12:52:26Z',
#   '@titaniumteddybear',
#   'Wait, so Mamdani is supposed to be both a &quot;Jihadist&quot; (i.e. a religious extremist) and also a &quot;communist&quot; (i.e. someone who believes that all religion is evil). Okey dokey.',
#   0],
#  ['2025-11-25T12:51:27Z',
#   '@rociocarranzabrito3883',
#   'He fell in love with Z because YT is sooooooo boring. Some color adds more flavor. I hope he gets it now',
#   0],
#  ['2025-11-25T12:46:25Z',
#   '@FeenixT',
#   'Trump is like this with the French president too. Its so funny to watch. Just for context, France is a democratic socialist country.',
#   0],
#  ['2025-11-25T12:45:45Z',
#   '@Souliteracy',
#   '<a href="https://www.youtube.com/watch?v=wiIdWIgmevw&amp;t=14">0:14</a> he looks just how he looks in South Park 😂',
#   0],
#  ['2025-11-25T12:41:28Z',
#   '@bsedhs',
#   '<a href="https://www.youtube.com/watch?v=wiIdWIgmevw&amp;t=395">6:35</a> .............and trump calls cnn reporters rude??  What a wild question.',
#   0],
#  ['2025-11-25T12:40:31Z',
#   '@jaohonaxa',
#   'Between this and the saudi prince visit I&#39;m starting to wonder if trump has a secret fetish of being dominated by Muslim men.',
#   0],
#  ['2025-11-25T12:40:06Z',
#   '@monkeeseemonkeedoo3745',
#   'Mamdani brought more press than anyone, so yeah trump likes that.<br><br>Given his endorsement of jeffries I fear he will be a new obama.',
#   0],
#  ['2025-11-25T12:39:15Z',
#   '@deonthegreat5872',
#   'Should have had the Paul Rudd texts turn green',
#   0],
#  ['2025-11-25T12:39:14Z', '@cybermafia2828', 'Mamdani 🔥', 0],
#  ['2025-11-25T12:39:07Z',
#   '@johnholland9371',
#   'If the Democrats were actually competent then Mamdani WOULD be the future of the party.',
#   0],
#  ['2025-11-25T12:38:58Z', '@viclizardi6152', 'Trump mamando Mamdani', 0],
#  ['2025-11-25T12:37:49Z',
#   '@rivkaolleyphd',
#   'It would be funny if the school yard bully wasn&#39;t destroying America.',
#   0],
#  ['2025-11-25T12:37:06Z',
#   '@terryg4415',
#   'Ooh, I hope this isn&#39;t a case of Trump being told that everyone he endorses loses. Could he be trying to jinx Mamdani? The Curse of the Don.',
#   0],
#  ['2025-11-25T12:34:45Z',
#   '@canadiangirl5119',
#   'The felon wants something as usual…. Everything that the little puppets state is what the felon is….',
#   0],
#  ['2025-11-25T12:32:42Z',
#   '@test_handle_01',
#   'Easy to charm a snake. Or so ive heard.',
#   0],
#  ['2025-11-25T12:32:30Z',
#   '@Boris-z5u',
#   'By capitulating before putin/Kim/Xi (trade wars, red carpet in Alaska and &quot;peace plan&quot;) president betrayed and abused not only American standing in the world for centuries but fallen US soldiers in Vietnam and elsewhere. All administration&#39;s actions are totally anti American but billions in pockets are real! Impeachment and government replacement is a must ASAP! US may not survive - let&#39;s not wait until midterms..',
#   0],
#  ['2025-11-25T12:31:50Z',
#   '@towermoss',
#   'Trump is two-faced and devoid of any convictions. How else would this meeting could have gone?',
#   0],
#  ['2025-11-25T12:31:45Z',
#   '@ginnymeljac2300',
#   'Jesse Watters from FOX NEWS is NOT HOT!  His own Mother won’t invite him to thanksgiving!',
#   0],
#  ['2025-11-25T12:30:43Z',
#   '@DanG802',
#   'I&#39;m going to New York City in December and just wondering where to get that molly Trump took and a bag of them Duritos? Asking for me.',
#   0],
#  ['2025-11-25T12:28:25Z',
#   '@noplace3571',
#   'Never interrupt your enemy when he&#39;s making a mistake. Mamdani just has to smile and stand there, and let Trump show the world how easy he is to play 😂',
#   0],
#  ['2025-11-25T12:28:00Z',
#   '@MegaSmk',
#   'come on, donnie. as if you knew what a &quot;despot&quot; was.. and of course you&#39;ve been called worse - in thousands of variations and every language of the world.',
#   0],
#  ['2025-11-25T12:27:27Z',
#   '@SyntheticFuture',
#   'I find it pretty insane that media can just call someone a Jihadist with 0 proof and there&#39;s zero consequences... what the heck...',
#   0],
#  ['2025-11-25T12:27:17Z',
#   '@baronvonbunghole5999',
#   '&quot;It&#39;s okay, you can call me a fascist 😊❤️✨️&quot;&quot;',
#   1],
#  ['2025-11-25T12:27:00Z',
#   '@thetommantom',
#   '1 in 10 trump voters voted for him and he so proud lol the whole time trump just bluffing to see if he could get him to do something stupid like that',
#   0],
#  ['2025-11-25T12:26:16Z',
#   '@CaliExile',
#   'Within 72 hrs, the pigmessiah will be claiming the opposite.  No principles, no rudder.',
#   0],
#  ['2025-11-25T12:26:05Z',
#   '@hairtoss7975',
#   'Trump failed his Saving Throw against a Level 1 Charm.',
#   0],
#  ['2025-11-25T12:24:23Z',
#   '@nikkioh7584',
#   'He don’t keep touching him for no reason….😒',
#   0],
#  ['2025-11-25T12:21:20Z',
#   '@TracyAllenPreplanner',
#   'What a letdown for the press 😂 They just knew that they and Trump were going to destroy him 😒💪🏽🩵',
#   0],
#  ['2025-11-25T12:21:06Z',
#   '@Pidxr',
#   'Those who can do, those who can&#39;t FOX',
#   0],
#  ['2025-11-25T12:20:45Z',
#   '@zaaz1471',
#   'OMG.. that wardrobe malfunction at the end 🤮',
#   0],
#  ['2025-11-25T12:18:51Z',
#   '@bubach85',
#   'You could make good money selling a transcript of that meeting. It needs to be studied. 😳',
#   0],
#  ['2025-11-25T12:17:58Z',
#   '@zaaz1471',
#   'T****&#39;s motto: If you can&#39;t beat them, suck up to them.',
#   0],
#  ['2025-11-25T12:15:01Z',
#   '@MechaDragonEagle',
#   'Mamdani fucking Rocks... This is how I want the news to be like all the time.. Fan fucking Tastic... I love the memes that are like Mamdani Flip your Hair again we Need Free Healthcare ! xD',
#   0],
#  ['2025-11-25T12:14:33Z',
#   '@johnhenderson131',
#   'That gave me whiplash, how did Trump reverse direction so fast!?',
#   0],
#  ['2025-11-25T12:13:25Z',
#   '@cicalinarrot',
#   'There&#39;s not reason but racism to say Mamdani looks bad.<br>And there&#39;s no reason but dementia to say Trump looks better.',
#   0],
#  ['2025-11-25T12:13:22Z',
#   '@Marvinmartion',
#   'Just remember every republican accusation is a confession! Every single time!',
#   0],
#  ['2025-11-25T12:13:00Z',
#   '@loveyourcountrynotyourpart6182',
#   'That shows how scared are white people to have a brown guy govern, He can&#39; be any worth than what we already have.',
#   0],
#  ['2025-11-25T12:12:28Z',
#   '@twilightgardenspresentatio6384',
#   'Trump is an easy mark',
#   0],
#  ['2025-11-25T12:04:40Z',
#   '@Marvinmartion',
#   'That image of trump smiling at  Mandani makes me think of South Park! Immediately!',
#   0],
#  ['2025-11-25T12:04:33Z',
#   '@TtumpsNeckVagina',
#   'Ttump is a weak little boy that caves while in the presence of real men.',
#   0],
#  ['2025-11-25T12:02:15Z',
#   '@andysalter7779',
#   'Trump remembered he owns a lot of property in NY and he doesn&#39;t want to devalue it.',
#   0],
#  ['2025-11-25T12:02:07Z',
#   '@jimckain',
#   'I think we just learned who holds the photo of Trump blowing Bubba.',
#   0],
#  ['2025-11-25T12:01:02Z',
#   '@rowynnecrowley1689',
#   'This makes me very suspicious of Mamdani. Trump doesn&#39;t just change his mind. Especially about someone on the left. More especially when that leftie has a name like Zohran Mamdani.',
#   0],
#  ['2025-11-25T12:00:59Z',
#   '@justinmolinari229',
#   'Trump just was trying to shame Jeffries and Chuck…',
#   0],
#  ['2025-11-25T12:00:00Z',
#   '@sporer_',
#   '<a href="https://www.youtube.com/watch?v=wiIdWIgmevw&amp;t=616">10:16</a> not the nipple out!!! 😂',
#   0],
#  ['2025-11-25T11:57:50Z',
#   '@pleasedtoreadyou',
#   'I don&#39;t want to torture Zohran but I need him to spend more time at the Oval Office. This has been so damn wild, I need mooooooore 😬',
#   0],
#  ['2025-11-25T11:57:44Z',
#   '@essiebessie661',
#   'Trump is delighted because someone told him Mamdani isn’t qualified to be POTUS, and so won’t be running against him.',
#   0],
#  ['2025-11-25T11:55:40Z', '@Cha1933', 'All Republicans are liars', 0],
#  ['2025-11-25T11:55:01Z',
#   '@susanj.5693',
#   'Mamdami&#39;s mom is in the mo ie business and his dad isnt bad off either.  Don like shiny things and connected people. Plus the new Mayor is clearly well learned in communication and negotiations. Mamdami is really showing well, it builds him to a platform thats set pretty high. I  hope he remembers to take it 1 project at a time. He has to start and finish well.  Dont let the people down, Sir. More than NYC is watching, if he pulls this off, it would be massive.',
#   0],
#  ['2025-11-25T11:53:49Z',
#   '@raullorenzo3076',
#   'Trump, always surrounded by idiots and morons with no intelligence whatsoever!😮',
# ...
#   '@evolblue8614',
#   'How does Trump actually think he looks like a good person. He&#39;s like a real life caricature and the village idiot all in one. The whole world laughs at this guy.',
#   0],
#  ['2025-11-25T08:35:03Z',
#   '@hansdampf6916',
#   'Even when Trump does good he gets mocked for it.',
#   0],
#  ['2025-11-25T08:34:37Z',
#   '@olivierlusseyran',
#   '&quot;You can call me a fascist&quot; : Yes I Will ! &amp; Musk calling someone a &quot;charismatic swindler&quot; is very funny !',
#   0],
#  ['2025-11-25T08:33:05Z',
#   '@finnishview2933',
#   'USA politics is so weird. I wonder if anyone in GOP even know what word communist actually mean?',
#   0],
#  ['2025-11-25T08:32:34Z',
#   '@Livingthedreaminparadise',
#   'It just dawned on me that Barack and Michelle must sit in bed and watch this s*** and just laugh their f*<b>***</b> heads off. Or cry.',
#   0],
#  ['2025-11-25T08:30:07Z',
#   '@JonOhFun',
#   'Mamdani 100% walked into that meeting, slapped down photos of Trump getting a golden shower from Elmo &amp; Big Bird and just did the &#39;I&#39;m the captain now&#39; meme!<br>It&#39;s the only explanation 😂',
#   0],
#  ['2025-11-25T08:29:43Z',
#   '@SteveJohnson-fy7qr',
#   'There will never be a moment when you can trust Trump. Never. Do not do it.',
#   0],
#  ['2025-11-25T08:28:27Z',
#   '@frankingram3477',
#   'Trump&#39;s a low hinging rotten fruit. Shower him with compliments and he&#39;s giddy like a little girl. All foreign diplomats use this tactic on him. The simpleton falls for it every time.',
#   0],
#  ['2025-11-25T08:26:13Z',
#   '@coyley72',
#   'Trump: &quot;I think I&#39;ll be helping him, not hurting him&quot; <br>I don&#39;t understand why he would hurt any one regardless of party. Trump is so vile.',
#   10],
#  ['2025-11-25T08:26:07Z',
#   '@emy-j',
#   'Scare tactics of the right and the liberal democrats. I think it’s important to point out that the democrats didn’t want to embrace him. The democratic party wanted Cuomo. AIPAC and other big PACs + billionaires would that fund them wouldn’t want them to. Liberal democrats don’t want actual leftists that could enact meaningful change.',
#   1],
#  ['2025-11-25T08:34:58Z',
#   '@ferula96',
#   'Haha. Nope. Only trump endorsed Cuomo. Not 1 Dem endorsed Cuomo. But several Dem leaders- Hillary Clinton. Hakeem Jeffries. AIC. Sen Sanders Sen Warren. Gov Newsom. Gov Hochul of NY all endorsed MAMDAMI.',
#   0],
#  ['2025-11-25T08:26:05Z',
#   '@let_me_out_b4_i_dye',
#   'Do these people even know what Communism is? SMDH.',
#   0],
#  ['2025-11-25T08:24:56Z',
#   '@Eeman.2205',
#   'When there is a will nightmares turn intro dreams come true. Positive years (minds) ahead. Love this show ❤',
#   0],
#  ['2025-11-25T08:24:20Z',
#   '@valiaudet3415',
#   'Did Mumdani agree with a new trump tower in New York? What happened to have trump kissing and smiling ?😮',
#   0],
#  ['2025-11-25T08:21:51Z',
#   '@mrdirachiel',
#   'Seriously though, Trump COULD be on strong painkillers for his very obvious health problems, which explains both the weird Love In and the midnight Truth Social rants.',
#   0],
#  ['2025-11-25T08:35:47Z',
#   '@ferula96',
#   'It is called cerebral dementia. Symptoms: fits of rage. Being incoherent. Confused of where they are. Very sleepy. Then waves of sweetness. Acts very childlike and throws childlike rage tantrums. Listens to same song very loud repeatedly',
#   1],
#  ['2025-11-25T08:20:14Z',
#   '@btrueeth',
#   'Trump has no qualms doing a u-turn on Mamdani. He can change his mind at a drop of a dime. He&#39;s probably setting Mamdani up for failure.',
#   0],
#  ['2025-11-25T08:20:00Z',
#   '@GabrielAdrianSamfira',
#   'Mamdani found the factory reset button on the guy.',
#   0],
#  ['2025-11-25T08:19:47Z', '@cgomes1607', 'What is happening ??', 0],
#  ['2025-11-25T08:19:26Z',
#   '@pjdarcy',
#   'Surely Mamdani can sue for defamation, any news outlet calling him a Jihadist, no?',
#   0],
#  ['2025-11-25T08:19:22Z',
#   '@Nigel-p5j',
#   'America&#39;s biggest mistake diaper don 💩 DJT KKK STINKY 💩',
#   1],
#  ['2025-11-25T08:18:54Z',
#   '@MarcoSefling',
#   'Hey you wana go up on the roof? Lol😂😂😂😂',
#   0],
#  ['2025-11-25T08:18:34Z',
#   '@johnchessant3012',
#   'Now imagine if we had 100 Zohrans in Congress. The Democrats who are there currently have largely forgotten that politics is the art of persuasion.',
#   1],
#  ['2025-11-25T08:14:16Z',
#   '@tmattoneill',
#   '&quot;Democratic Party&quot; not democrat party. You immediately sound like a total idiot if you say democrat party.',
#   0],
#  ['2025-11-25T08:13:42Z',
#   '@catdogman23',
#   '<a href="https://www.youtube.com/watch?v=wiIdWIgmevw&amp;t=135">2:15</a> okay that was good haha',
#   0],
#  ['2025-11-25T08:13:20Z',
#   '@asaraset9568',
#   'Boycott the USA. <br>Boycott the World Cup games in the USA!',
#   0],
#  ['2025-11-25T08:12:12Z',
#   '@benjaminhoratiogarvis7522',
#   'Tred carefully.  <br><br>How did he charm him?',
#   0],
#  ['2025-11-25T08:11:57Z',
#   '@asaraset9568',
#   'Soo good! <br>Smitten is such an understatement...I reckon he&#39;d like to blow this bubba too!!😂❤😂❤',
#   0],
#  ['2025-11-25T08:11:20Z',
#   '@TwoWrights',
#   'You mean Mamdani walked into the meeting with Trump, showed him an old photo he got from Russia, and Trump buckled like a belt.',
#   0],
#  ['2025-11-25T08:10:02Z',
#   '@victoriabaker4400',
#   '&quot;Dream come true&quot; --   Yeah that was my first thought when I heard that---  yeah, he&#39;s a dreamboat....  I used to never believe that gay men could be fasc!sts because I thought that the (shared) understanding we had of being harassed, beat up, etc would ensure that we would have empathy for others.  I had to learn better those decades ago, and here we are. I&#39;m convinced part of the Republican attacks on trans, queer, LGBTQIA+ people are a cover-- the worst homophobes are closet cases, drama queens reacting so no one will imagine they might be gay.  And yeah I can say all this sh!t because I&#39;m queer, I&#39;ve paid my dues, and I know what I&#39;m talking about.',
#   0],
#  ['2025-11-25T08:09:23Z',
#   '@lidelloste3317',
#   'It was merely a means to herd people into tiny areas, then kill them. Fish in a barrel',
#   0],
#  ['2025-11-25T08:08:04Z',
#   '@SweetBearCub',
#   'I have never seen Trump look up at anyone with that sort of pure joy on his face. Not even his wife.',
#   0],
#  ['2025-11-25T08:07:28Z',
#   '@Bastiaan12345-i',
#   'This is politics. For  obvious reasons he keeps the enemy close. And for good reasons this guy is very popular.',
#   0],
#  ['2025-11-25T08:05:12Z',
#   '@CalypsoStrawn42Dance',
#   'Don&#39;t mess with The Zohar?',
#   0],
#  ['2025-11-25T08:04:08Z',
#   '@Jonathan-ut3zh',
#   '🚂🚂🚀🚀🚀🛬🛬🛸🛬🛸🛬🛸🛬🛬🚀🚀🛸🛬🛬🛬🚀🚀🛬🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀…,,,,,,,,,,,,,,,~,,,?,?????,,,,,,,,,…|…|.||,,&gt;?&lt;???&lt;&lt;&lt;?&lt;&lt;&lt;&gt;&gt;?&gt;&lt;?&lt;&lt;&lt;&lt;&lt;&lt;~,~~~~~,~~~~~|||||||\\\\\\/:3:3:::;;;;(;((((((((()(((())))))))()()))6)666666666666666666)666))))))(;:///:;;;;;;;;;;;;;;;;;;;;(((((((((((((((((((((((()))()))))))))))))))))))))))))))$)$$!$$!!!!!!$))(;;;;;;;;;,;,;,;,;;,:::;;;:::;;;;;;;;,;…:::::;;;;_………..//.:::;;;;;(((((,,,(,,,;;;;;;;(((((((((((((((()(()(((((())))))))))))$))))))((((((((())))))))((((((((((;;;;::;;(((((((((((((((((((((((()))))())((()))))))))$$&amp;&amp;&amp;&amp;&amp;&amp;&amp;&amp;’',
#   0],
#  ['2025-11-25T08:03:40Z',
#   '@Hahvok',
#   'It was pretty amusing to watch all of the pre-meeting media calling him zoRON, and Mamdami, to then immediately starting saying his name correctly the very second they realized Trump was gobbling that knob.',
#   0],
#  ['2025-11-25T08:03:19Z', '@remeshpanicker', 'Sean Hannity has friends?', 0],
#  ['2025-11-25T08:02:55Z',
#   '@JamesMcGee-i9n',
#   'How could he be a communist and a Jihadist? Wouldn&#39;t they be diametrically opposed?',
#   0],
#  ['2025-11-25T08:02:49Z',
#   '@lordcaptain73',
#   'That chia pet was so good and I feel like I need to make one for my kitchen window',
#   0],
#  ['2025-11-25T08:01:55Z',
#   '@someoddpages',
#   'Trump folds when he knows he&#39;s lost the fight and tries to swivel out of the loss by co-opting his opponent&#39;s win.  He did the same when he lost the Senate vote to release the <a href="http://www.youtube.com/results?search_query=%23epstein">#Epstein</a> files.  He behaves just like a coward who&#39;s been punched on the nose and knows his opponent isn&#39;t afraid of him in any way.',
#   0],
#  ['2025-11-25T08:00:43Z',
#   '@PBTophie',
#   'This just makes me more suspicious of Mamdani than I already was. The past several years have been the height of political theater and double-dealers. Mamdani comes off as the premier of these showstopping turncoats; using every trick in the book to get the vote.<br>Maybe he&#39;s sincere -- I&#39;m still willing to give him the benefit of the doubt -- but this is smelling pretty bad.',
#   0],
#  ['2025-11-25T08:00:25Z',
#   '@DocHolidaydaisyifyoudo',
#   'I&#39;ll hate the word communist when you hate that kids are hungry while you stuff your wealthy holes with Steak &amp; Lobster.',
#   1],
#  ['2025-11-25T08:00:20Z',
#   '@rTodd-g8e',
#   'if he is OK why did they not use one of the two MRI machines in the white house????',
#   0],
#  ['2025-11-25T08:00:01Z',
#   '@Jonathan-ut3zh',
#   '🚙🚙🚙🚙🛩️🛩️🚉🚊🚊🚊🚊🚉🚊🚊🚊🚊🚊🚉🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚉🚊🚉🚈🚂🚂🚂🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚊🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚈🚊🚈🚈🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚊🚉🚉🚉🚉🚉🚂🚂🚂🚂🚂🚝🛸🚤🚤🚤🚤🚤🚤🚤🚤🚤🚤🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛩️🛩️🛩️🛩️🛩️🛩️🛬🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛬🛩️🛩️🛩️🛩️🛬🛩️🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛩️🛬🛸🛩️🛩️🛸🚀🛬🛬🛬🛬🛩️🛬🛬🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛬🚀🛬🛸🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🛸🚀🚀🚀🚀🛸🚀🚀🚀🚀🛬🚀🚀🛸🚀🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛬🛬🛬🛬🛬🛩️🛬🛬🛩️🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛬🛩️🛬🛬🛩️🛬🛬🛬🛩️🛬🛬🚀🛬🚀🚀🚀🚀🛸🚀🛩️🛬🛬🛸🛬🛬🚀🛸🛸🛬🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛩️🛸🛸🛸🛸🛸🛸🛸🛸🛸🛸🛩️🛩️🛩️🛸🚤🚤',
#   0],
#  ['2025-11-25T07:59:42Z',
#   '@goldenstate66',
#   'Imagine how many Maga brains short circuited after they saw this on the news.',
#   0],
#  ['2025-11-25T07:59:32Z',
#   '@CalypsoStrawn42Dance',
#   'This is cray cray!  I never thought it could be.  Did Mamdani give him the molly?  Honestly, they both look a little high to me.  Did they shoot special K or what???',
#   0],
#  ['2025-11-25T07:59:12Z',
#   '@dennisjay1101',
#   'Might be time for Trump to take one of his &quot;guess which animal this is&quot; IQ tests',
#   0],
#  ['2025-11-25T07:58:44Z',
#   '@TheDanishGuyReviews',
#   'A reminder that Communism is an old-fashioned ideology, so if you spew hatred against it, your mentality is 30 years out of date, and you probably shouldn&#39;t be listened to about anything.',
#   3],
#  ['2025-11-25T13:42:52Z',
#   '@00SmileTime00',
#   'Yeah that&#39;s all completely wrong lol.<br><br>In terms of major political ideologies Communism is the <i>youngest</i> by at least 150 years depending on when you measure from, also the Soviet Union was not Communist so your &quot;30 years&quot; count is also wrong.<br><br>You have no idea what the word Communism means.',
#   0],
#  ['2025-11-25T13:54:21Z',
#   '@TheDanishGuyReviews',
#   '@00SmileTime00  Neither does any Conservative. Also, if the Soviet Union wasn&#39;t Communist, there would have been no Red Scare, so that&#39;s just not true.',
#   0],
#  ['2025-11-25T14:19:15Z',
#   '@00SmileTime00',
#   '\u200b\u200b\u200b@TheDanishGuyReviewsAgain completely wrong. I&#39;m not a conservative so thats irrelevant. American politicians fearmongering about Communism doesn&#39;t make their adversaries communist. By that logic Haitian migrants were actually eating cats and dogs because otherwise there would have been no story about it <br><br>Actually think about what you&#39;re suggesting for <i>two seconds</i><br>You have no idea what this word means. I literally cannot make this any simpler for you 🤷',
#   0],
#  ['2025-11-25T14:26:20Z',
#   '@TheDanishGuyReviews',
#   '\u200b@00SmileTime00 It is very relevant that I mention Conservatives, because they&#39;re the ones complaining about this constantly. No Democrat has been calling anyone Communist for years. And it doesn&#39;t matter if I know what it means or not, I&#39;m not the one calling everyone Communist, the Conservatives are. Tell that to all of them first.',
#   0],
#  ['2025-11-25T15:09:59Z',
#   '@00SmileTime00',
#   '\u200b@TheDanishGuyReviewsKamala Harris called Trump a Communist dictator just a few months ago. Again literally everything you said is wrong.',
#   0],
#  ['2025-11-25T07:58:38Z',
#   '@Jonathan-ut3zh',
#   '🫒🧄🫑🫑🫑🫑🫑🫑🫑🫑🫑🫑🌽🫑🫑🌽🫑🌽🌽🧄🧄🧄🧅🧅🧄🫑🫑🫑🫑🧄🌽🌽🫑🌽🌽🌽🫑🫑🌽🌽🫑🧄🧄🧄🧄🧄🧅🧅🧅🧄🧄🧄🧄🧄🧄🧅🧄🧅🧅🧅🌽🌽🌽🫑🧄🧅🧅🧄🧄🧄🧄🧄🧄🧄🧄🧄🧄🧄🧄🧄🧄🧄🧄🧄🍠🍠🧄🧄🍠🍠🍠🍠🍠🍠🍠🍠🍠🍠🍠🍠🍠🫚🍠🧅🧅🧅🌽🌽🌫️🌫️🌫️☔️☔️☔️☔️☔️☔️☔️☂️☔️☔️☔️☔️☂️☂️☔️☔️🌫️🌫️🍊🍊🍊🍊🍊🍉🍉🍉🍉🍊🍊🍊🍊🍊🍊🍊🍊🍊🍊🍊🍉🍊🍉🍉🍉🍉🍉🍉🍉🍉🍉🍉🍌🍉🍊🍊🍊🍊🍊🍊🍊🍐🍐🍐🍐🍐🍐🍐🍐🍐🍐🍐🍐🍐🍐🍐🍐🍐🍊🍊🍊🍊🍊🍊🍊🍐🍐🍐🍐🍊🍐🍐🍐🍐🍐🍐🍐⛅️⛅️⛅️⛅️🌥️🌥️🌥️🌥️🌥️🌈🌈🌤️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️🌧️⛅️⛅️🌧️🌧️🌧️⛈️🌧️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️🌧️🌧️🌧️🌧️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️🌥️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️🌈⛅️⛅️⛅️⛅️🌥️⛅️⛅️🌥️⛅️⛅️⛅️⛅️🌥️🌥️⛅️⛅️🌥️⛅️⛅️🌥️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️⛅️🌥️🌥️🌥️🌥️🌥️🌥️⛈️🌥️🌥️🌥️🌥️🌥️🌥️🌥️🌥️🌥️⛈️⛈️🌧️⛈️⛈️⛈️⛈️🌥️🌥️🌥️🌥️🌈🌥️💧☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️☂️🎥🎥🎥📼📼📼🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🏎️🚓🚓🚕🚙🚙🚙🚌🚙🚙🚌🚌🚌🚌🚌🚌🚌🚌🚌🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🚲🚲🚲🚲🚎🚕🚕🚙🚙🚙🚙🚌🚌🚌🚌🚌🚌🚌🚙🚙🚙🚙🚌🚌🚙🚌🚌🚙🚙🚙🚌🚙🚙🚌🚌🚙🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚙🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚌🚙🚌🚌🚙🚙🚙🚙🚙🚌🚌🚌🚌🚌🚌🚌🚌🚚🚚🦽🦽🦽🦽🦽🦽🦽🦽🦽🩼🩼🛴🩼🩼🩼🛴🛴🛴🚲🛞🛺🛞🚲🚲🛴🛴🛴🛴🛴🛴🚲🚲🚲🚲🚲🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛺🛞🛺🛺🛺🛺🛺🛺🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛞🛺🛺🛴🛴🩼🩼🩼🛴🛺🛴🛴🛴🛺🛺🛺🛺🩼🛴🩼🩼🚜🚜🚜🚜🚐🚐🚐🚐🛻🚓🏎️🏎️🚓🏎️🚓🚓🚓🚓🚓🚓🚓🚓🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚙🚓🚓🚓🚓🚓🚓🚙🚓🚓🚓🚓🚓🚓🚙🚙🚌🚙🚓🚑🚓🚑🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚓🚑🚓🚓🚓🚓🚑🚓🚓🚓🚑🚓🚑🚑🚓🚑🚑🚓🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚌🚌🚌🚌🚌🚙🚌🚌🚌🚌🚌🚑🚑🚓🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚓🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚑🚓🚑🚑🚚🚚🚚🚚🚚🚚🚚🚚🚚🚚🚚🛻🚚🚚🚚🚑🛻🚚🛻🚚🚚🚚🚓🚚🚚🛻🚚🚚🚚🚚🚚🛻🚚🚚🛻🛻🛻🚚🚚🛻🛻🚚🛻🛻🚚🛻🛻🦯🦯🦯🦯🦯🦯🦯🦯🦯🦯🦯🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🦽🚚🚚🚚🚑🚑🚑🚓🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🛻🚐🚐🚐🚐🚐🚐🚐🚐🛻🚐🚐🚜🚜🦯🚜🚜🦯🚜🚜🚜🚜🦯🚜🦯🦯🦯🦯🦯🦯🦯🦯🦯🦯🦯🦯🦯🦯🛴🦯🦯🦯🦯🦯🦯🚲🚲🚲🚲🚲',
#   0],
#  ['2025-11-25T07:58:11Z',
#   '@twitteringothers5059',
#   'I predict two things - <br><br>1. Trump will be making more trips to New York City than Mar-A-Lago <br><br>2. Trump will have slip of the tongues and instead of calling Zohran Mamdani he will call him Zohran Mydaddy',
#   0],
#  ['2025-11-25T07:57:56Z',
#   '@nataschavisser573',
#   'I am currently carrng for my mother who has dementia. These interactions people have with Trump is painful to witness. Sure, he is an evil and selfish man, but he is also clearly not well.',
#   0],
#  ['2025-11-25T07:57:33Z',
#   '@manda60',
#   'Sean Hannity needs to go back to his job as a creepy sentient ventriloquist&#39;s doll.',
#   0],
#  ['2025-11-25T07:57:29Z',
#   '@LeonaElchuk',
#   'Be afraid, Hannity. Be very afraid.',
#   1],
#  ['2025-11-25T07:57:23Z',
#   '@SSBroly965',
#   'It will be so good to not have to hear trump&#39;s shrill voice someday when is is gone or in prison.',
#   0],
#  ['2025-11-25T07:57:19Z',
#   '@Norrinsgirl',
#   'Has Trump been at the gummy bears?',
#   0],
#  ['2025-11-25T07:56:42Z',
#   '@lorihawkins7016',
#   'He literally charmed him....🐍',
#   0],
#  ['2025-11-25T07:56:38Z',
#   '@Catliness',
#   'Oh boy, Elon is so jealous of Mumdani!',
#   0],
#  ['2025-11-25T07:56:34Z',
#   '@twitteringothers5059',
#   'As a side note, I&#39;ve seen people condemning Zohran for meeting Trump. Some called him a sellout ;  at least called him a fascist for just standing next to Trump. Sadly but unsurprisingly these people don&#39;t realize that Zohran Mamdani came to DC, walked into the White House, talked to Trump and stood in the Oval Office taking questions as Mayor-Elect Mamdani. <br><br>As Mayor-Elect, he needs to carry a different vibe and different way of doing business than Candidate Mamdani as long as he still stood by his principles and by all his campaign promises which he did.  Zohran came out of that meeting totally uncompromised. <br><br>It is Trump who changed his mind. Trump went from threatening to withhold funds to wanting help Zohran. Zohran even made Trump OK with him still thinking that Trump is a fascist. <br><br>This does not make him a sellout. This makes him a statesman.',
#   0]]

# %% [markdown]
# #4. Ubah Hasil Crawling ke Dataframe

# %%
df = pd.DataFrame(comments, columns=['publishedAt', 'authorDisplayName', 'textDisplay', 'likeCount'])
df
# Out:
#               publishedAt      authorDisplayName  \
# 0    2025-11-25T16:41:28Z            @tommyt1971
# 1    2025-11-25T16:40:53Z     @patrickhowell5578
# 2    2025-11-25T16:38:29Z        @thomasdeas1941
# 3    2025-11-25T16:37:40Z             @AzzöNözzö
# 4    2025-11-25T16:34:50Z       @sepiasnakesigil
# ..                    ...                    ...
# 495  2025-11-25T07:57:23Z            @SSBroly965
# 496  2025-11-25T07:57:19Z           @Norrinsgirl
# 497  2025-11-25T07:56:42Z       @lorihawkins7016
# 498  2025-11-25T07:56:38Z             @Catliness
# 499  2025-11-25T07:56:34Z  @twitteringothers5059
#
#                                            textDisplay  likeCount
# 0    Makes me think that T***p got sick of Florida ...          0
# 1    WOW, literally WOW!<br>Fox &amp; MAGA must be ...          0
# 2    Trumps voice is constantly horse, to many blow...          0
# 3    Does Putin have any pornographic pictures of T...          1
# 4    Good for Mamdani, but I wonder how big the ove...          0
# ..                                                 ...        ...
# 495  It will be so good to not have to hear trump&#...          0
# 496                 Has Trump been at the gummy bears?          0
# 497                      He literally charmed him....🐍          0
# 498             Oh boy, Elon is so jealous of Mumdani!          0
# 499  As a side note, I&#39;ve seen people condemnin...          0
#
# [500 rows x 4 columns]

# %% [markdown]
# #5. Simpan Hasil Crawling ke file CSV

# %%
df.to_csv('youtube-comments.csv', index=False)

# %% [markdown]
# # Ingin belajar lebih banyak lagi?
#
# Banyak video pembelajaran terkait Machine Learning yang disajikan di channel Youtube http://youtube.com/c/AchmadSolichin. Silahkan berkunjung dan jangan lupa **SUBSCRIBE** untuk membantu pengembangan channel dengan video-video berkualitas lainnya.
#
# ## Terima kasih, selamat belajar!
#
# Notebook ini dibuat oleh: <a href = "http://achmatim.net">Dr. Achmad Solichin</a> dengan acuan dari berbagai sumber:
# 1. https://www.geeksforgeeks.org/how-to-extract-youtube-comments-using-youtube-api-python/
#
# <hr>
# Copyright &copy; 2022 [Achmatim.Net](http://achmatim.net). This notebook and its source code are released under the terms of the CC License.​
